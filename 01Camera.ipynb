# %%
from plywood_gallery import ChapterManager

ChapterManager.clean_all(skip_warning=True)
# ChapterManager.clean("Camera Options")
ChapterManager.reset_counter()
ChapterManager.set_chapter_name("Camera Options")
# Out:
# This path and all its child elements will be removed:/Users/jan-hendrik/projects/napari-plywood-gallery/gallery_assets

# %%
# %%capture_png -p Template.png --celltype Header --style "width:140px"
# import matplotlib.pyplot as plt
# import napari
# from skimage import data
#
# from napari.settings import get_settings
#
# get_settings().application.window_position = (1000, 300)
# get_settings().application.window_fullscreen = False
# get_settings().application.window_statusbar = False
# get_settings().application.save_window_state = False
#
# viewer = napari.Viewer()
# viewer.theme = "light"
# viewer.dims.ndisplay = 3
# viewer.window.resize(800, 600)
# viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()
# viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()
#
#
# def make_screenshot(viewer=None, region=None):
#     img = viewer.screenshot(canvas_only=True, flash=False)
#     if region:
#         print(img.shape)
#         img = img[region[0] : region[1], region[2] : region[3]]
#     plt.imshow(img)
#     plt.axis("off")
#
#
# # make data
# blobs = data.binary_blobs(length=301, volume_fraction=0.1, n_dim=3, seed=42)
# blobs = blobs[200:, 200:, :-100]
# blobs[:, :, :50] = 1
#
# import matplotlib.pyplot as plt  # NOT
#
# fix, ax = plt.subplots(figsize=(5, 4), facecolor="#F7F5F3")  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)  # NOT
# ax.axis("off");  # NOT
# Out:
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_15553/3662813237.py:16: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_15553/3662813237.py:17: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()
# (0.0, 1.0, 0.0, 1.0)

# %%
# %%capture_png -p FirstView.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.layers.clear()
# viewer.dims.ndisplay = 3
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# layer1.opacity = 1
# make_screenshot(viewer)

# %%
# %%capture_png -p FirstView.png --celltype Normal --style "width:140px"
#
# viewer.reset_view()
# viewer.layers.clear()
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# layer1.opacity = 1
# make_screenshot(viewer)

# %%
# %%capture_png -p ShiftRIGHT.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.center = (50, 50, 0)
# make_screenshot(viewer)

# %%
# %%capture_png -p ShiftLEFT.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.center = (50, 50, 200)
# make_screenshot(viewer)

# %%
# %%capture_png -p ShiftUP.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.center = (50, 130, 100)
# make_screenshot(viewer)

# %%
# %%capture_png -p ShiftDOWN.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.center = (50, -50, 100)
# make_screenshot(viewer)

# %%
# %%capture_png -p TURN1.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (30, 0, 0)
# make_screenshot(viewer)

# %%
# %%capture_png -p TURN2.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (0, 30, 0)
# make_screenshot(viewer)

# %%
# %%capture_png -p TURN3.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (0, 0, 30)
# make_screenshot(viewer)

# %%
# %%capture_png -p TURN4.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# make_screenshot(viewer)

# %%
# %%capture_png -p ZOOMOUT.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# viewer.camera.zoom = 0.8
# make_screenshot(viewer)

# %%
# %%capture_png -p ZOOMIN.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# viewer.camera.zoom = 8
# make_screenshot(viewer)

# %%
# %%capture_png -p OPACITY.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.layers.clear()
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# viewer.camera.angles = (30, 40, 80)
# layer1.opacity = 0.4
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes.png --celltype Dependend --style "height:97px; width:auto"
# viewer.camera.zoom = 0.2
# viewer.axes.visible = True
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])
# Out:
# (1070, 1540, 4)

# %%
# %%capture_png -p AxesNoTips.png --celltype Dependend --style "height:97px; width:auto"
# viewer.axes.arrows = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])
# Out:
# (1070, 1540, 4)

# %%
# %%capture_png -p AxesNoColor.png --celltype Dependend --style "height:97px; width:auto"
# viewer.axes.colored = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])
# Out:
# (1070, 1540, 4)

# %%
# %%capture_png -p AxesDashed.png --celltype Dependend --style "height:97px; width:auto"
# viewer.axes.dashed = True
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])
# Out:
# (1070, 1540, 4)

# %%
# %%capture_png -p AxesNoLabels.png --celltype Dependend --style "height:97px; width:auto"
# viewer.axes.labels = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])
# Out:
# (1070, 1540, 4)

# %%
viewer.axes.visible = False

# %%
# %%capture_png -p IN2D.png --celltype Normal --style "width:140px"
# viewer.dims.ndisplay = 2
# layer1.opacity = 1
# viewer.dims.current_step = [92, 0, 0]
# make_screenshot(viewer)

# %%
# %%capture_png -p IN2DStep.png --celltype Normal --style "width:140px"
# viewer.dims.current_step = [90, 0, 0]
# make_screenshot(viewer)

# %%
# %%capture_png -p TextHelloNapari.png --celltype Normal --style "width:140px"
# viewer.text_overlay.visible = True
# viewer.text_overlay.text = "Hello Napari!"
# viewer.text_overlay.font_size = 40
# make_screenshot(viewer)

# %%
# %%capture_png -p ScaleBar.png --celltype Normal --style "width:140px"
# viewer.scale_bar.visible = True
# viewer.text_overlay.text = "ScaleBar"
# viewer.scale_bar.unit = "0.54um"
# viewer.scale_bar.font_size = 10
# make_screenshot(viewer)

# %%
viewer.scale_bar.visible = False
viewer.text_overlay.font_size = 35

# %%
# %%capture_png -p Axes_Order_012.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [0, 1, 2]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# viewer.dims.current_step = [10, 20, 30]
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes_Order_021.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [0, 2, 1]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes_Order_102.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [1, 0, 2]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes_Order_120.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [1, 2, 0]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes_Order_201.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [2, 0, 1]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)

# %%
# %%capture_png -p Axes_Order_210.png --celltype Normal --style "width:140px"
#
# viewer.dims.order = [2, 1, 0]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)

# %%
# %%capture_png -p RESTART.png --celltype Normal --style "width:140px"
# viewer.reset_view()
# viewer.scale_bar.visible = False
# viewer.text_overlay.visible = False
# viewer.layers.clear()
# make_screenshot(viewer)

# %%
# ChapterManager.clean("Camera Options")
