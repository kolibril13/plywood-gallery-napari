# %%
from plywood_gallery import ChapterConfig

ChapterConfig.clean_all(skip_warning=True)
ChapterConfig.generate_json()
#ChapterConfig.clean("Camera Options")
#ChapterConfig.clean("Axes")
#ChapterConfig.clean("2D")

ChapterConfig.reset_counter()
ChapterConfig.set_chapter_name("Camera Options")
# Out:
# Plywood Gallery v0.0.12
# This path and all its child elements will be removed:/Users/jan-hendrik/projects/all_plywood_galleries/napari/gallery_assets
# Deleted '/Users/jan-hendrik/projects/all_plywood_galleries/napari/gallery_assets' and all containing files and folder.
# Successfully created /Users/jan-hendrik/projects/all_plywood_galleries/napari/gallery_assets/gallery_parameters.json!🦫

# %%
# %%capture_png -p Template.png --celltype Header --style "width:120px"
# import matplotlib.pyplot as plt
# import napari
# from skimage import data
#                                                                              # NOT
# from napari.settings import get_settings                                     # NOT
#                                                                              # NOT
# get_settings().application.window_position = (1000, 300)                     # NOT
# get_settings().application.window_fullscreen = False                         # NOT
# get_settings().application.window_statusbar = False                          # NOT
# get_settings().application.save_window_state = False                         # NOT
# viewer = napari.Viewer()
# viewer.theme = "light"
# viewer.dims.ndisplay = 3
# viewer.window.resize(800, 600)                                               # NOT
# viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()       # NOT
# viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()           # NOT
#                                                                              # NOT
#                                                                              # NOT
# def make_screenshot(viewer=None, region=None):                               # NOT
#     img = viewer.screenshot(canvas_only=True, flash=False)                   # NOT
#     if region:                                                               # NOT
#         print(img.shape)                                                     # NOT
#         img = img[region[0] : region[1], region[2] : region[3]]              # NOT
#     plt.imshow(img)                                                          # NOT
#     plt.axis("off")                                                          # NOT
#                                                                              # NOT
#                                                                              # NOT
# # make data                                                                  # NOT
# blobs = data.binary_blobs(length=301, volume_fraction=0.1, n_dim=3, seed=42)
# blobs = blobs[200:, 200:, :-100]
# blobs[:, :, :50] = 1
#                                                                               # NOT
# import matplotlib.pyplot as plt                                               # NOT
#                                                                               # NOT
# %config InlineBackend.print_figure_kwargs = {'pad_inches':0}                  # NOT
#                                                                               # NOT
#                                                                               # NOT
# fix, ax = plt.subplots(figsize=(5, 4), facecolor="#F7F5F3")                   # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")    # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)                                    # NOT
# ax.axis("off");                                                               # NOT
# Out:
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_23642/538288027.py:15: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()       # NOT
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_23642/538288027.py:16: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()           # NOT
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.rcParams['figure.dpi'] = 70

# %%
# %%capture_png -p FirstView.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.layers.clear()
# viewer.dims.ndisplay = 3
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# layer1.opacity = 1
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p FirstView.png --celltype Normal --style "width:120px"
#
# viewer.reset_view()
# viewer.layers.clear()
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# layer1.opacity = 1
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ShiftRIGHT.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.center = (50, 50, 0)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ShiftLEFT.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.center = (50, 50, 200)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ShiftUP.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.center = (50, 130, 100)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ShiftDOWN.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.center = (50, -50, 100)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p TURN1.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (30, 0, 0)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p TURN2.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (0, 30, 0)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p TURN3.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (0, 0, 30)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p TURN4.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ZOOMOUT.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# viewer.camera.zoom = 0.8
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ZOOMIN.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.camera.angles = (30, 40, 80)
# viewer.camera.zoom = 8
# make_screenshot(viewer)  # NOT

# %%
ChapterConfig.set_chapter_name("Axes")

# %%
# %%capture_png -p OPACITY.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.layers.clear()
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# viewer.camera.angles = (30, 40, 80)
# layer1.opacity = 0.4
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes.png --celltype Dependend --style "height:83px; width:auto"
# viewer.camera.zoom = 0.2
# viewer.axes.visible = True
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])  # NOT
# Out:
# (1130, 1580, 4)

# %%
# %%capture_png -p AxesNoTips.png --celltype Dependend --style "height:83px; width:auto"
# viewer.axes.arrows = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])  # NOT
# Out:
# (1130, 1580, 4)

# %%
# %%capture_png -p AxesNoColor.png --celltype Dependend --style "height:83px; width:auto"
# viewer.axes.colored = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])  # NOT
# Out:
# (1130, 1580, 4)

# %%
# %%capture_png -p AxesDashed.png --celltype Dependend --style "height:83px; width:auto"
# viewer.axes.dashed = True
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])  # NOT
# Out:
# (1130, 1580, 4)

# %%
# %%capture_png -p AxesNoLabels.png --celltype Dependend --style "height:83px; width:auto"
# viewer.axes.labels = False
# make_screenshot(viewer=viewer, region=[440, 700, 700, 900])  # NOT
# Out:
# (1130, 1580, 4)

# %%
viewer.axes.visible = False

# %%
ChapterConfig.set_chapter_name("2D")

# %%
# %%capture_png -p IN2D.png --celltype Normal --style "width:120px"
# viewer.dims.ndisplay = 2
# layer1.opacity = 1
# viewer.dims.current_step = [92, 0, 0]
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p IN2DStep.png --celltype Normal --style "width:120px"
# viewer.dims.current_step = [90, 0, 0]
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p TextHelloNapari.png --celltype Normal --style "width:120px"
# viewer.text_overlay.visible = True
# viewer.text_overlay.text = "Hello Napari!"
# viewer.text_overlay.font_size = 40
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p ScaleBar.png --celltype Normal --style "width:120px"
# viewer.scale_bar.visible = True
# viewer.text_overlay.text = "ScaleBar"
# viewer.scale_bar.unit = "0.54um"
# viewer.scale_bar.font_size = 10
# make_screenshot(viewer)  # NOT

# %%
viewer.scale_bar.visible = False
viewer.text_overlay.font_size = 35

# %%
# %%capture_png -p Axes_Order_012.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [0, 1, 2]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# viewer.dims.current_step = [10, 20, 30]
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes_Order_021.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [0, 2, 1]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes_Order_102.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [1, 0, 2]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes_Order_120.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [1, 2, 0]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes_Order_201.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [2, 0, 1]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p Axes_Order_210.png --celltype Normal --style "width:120px"
#
# viewer.dims.order = [2, 1, 0]
# viewer.text_overlay.text = f"axes order = {viewer.dims.order}"
# make_screenshot(viewer)  # NOT

# %%
# %%capture_png -p RESTART.png --celltype Normal --style "width:120px"
# viewer.reset_view()
# viewer.scale_bar.visible = False
# viewer.text_overlay.visible = False
# viewer.layers.clear()
# make_screenshot(viewer)  # NOT
