# %%
from plywood_gallery import ChapterConfig

#ChapterConfig.clean("Viewer Interface")
ChapterConfig.reset_counter()
ChapterConfig.set_chapter_name("Viewer Interface")
# Out:
# Plywood Gallery v0.0.12

# %%
# %%capture_png -p FirstView.png --celltype Header --style "height:200px; width:auto;"
#
# import napari
# import matplotlib.pyplot as plt
# from skimage import data
#
# %config InlineBackend.print_figure_kwargs = {'pad_inches':0} # NOT
#
#
# def make_screenshot(viewer):
#     img = viewer.screenshot(canvas_only=False, flash=False)
#     plt.imshow(img)
#     plt.axis("off")
#
#
# # make data
# blobs = data.binary_blobs(length=301, volume_fraction=0.1, n_dim=3, seed=42)
# blobs = blobs[200:, 200:, :-100]
# blobs[:, :, :50] = 1
#
# viewer = napari.Viewer()
# viewer.theme = "dark"
# viewer.dims.ndisplay = 3
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# viewer.camera.angles = (30, 40, 80)
# layer1.opacity = 1
# make_screenshot(viewer)

# %%
# %%capture_png -p NewTheme.png --celltype Normal --style "height:200px; width:auto;"
# viewer.theme = "light"
# make_screenshot(viewer)

# %%
viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()
# Out:
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_24143/871948272.py:1: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()

# %%
# %%capture_png -p SecondView.png --celltype Normal --style "height:200px; width:auto;"
# # this is how to hide the LayerControls, but there might be a pulbic function for that in future:
# # viewer.window.qt_viewer.dockLayerControls.toggleViewAction().trigger()
# make_screenshot(viewer)

# %%
viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()
# Out:
# /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/ipykernel_24143/3807090861.py:1: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()

# %%
# %%capture_png -p SecondView.png --celltype Normal --style "height:200px; width:auto;"
# # this is how to hide the LayerList, but there might be a pulbic function for that in future:
# # viewer.window.qt_viewer.dockLayerList.toggleViewAction().trigger()
# make_screenshot(viewer)

# %%
# %%capture_png -p Height.png --celltype Normal --style "height:200px; width:auto;"
# # first option to do this, but not recommended as it changes the defaults:
# # from napari.settings import get_settings
# # get_settings().application.window_size = (1200, 565) # default(723, 565)
# # better option:
# viewer = napari.Viewer()
# viewer.window.resize(1200, 565)
# viewer.dims.ndisplay = 3
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
#
# viewer.camera.angles = (30, 40, 80)
# layer1.opacity = 1
#
#
# make_screenshot(viewer)

# %%
# %%capture_png -p Height.png --celltype Normal --style "height:200px; width:auto;"
# viewer.window.resize(723, 1200)
# make_screenshot(viewer)

# %%
# %%capture_png -p Height.png --celltype Normal --style "height:200px; width:auto;"
# from napari.settings import get_settings
#
# get_settings().application.save_window_state = False
# get_settings().application.window_position = (800, 300)
#
# viewer = napari.Viewer()
# viewer.text_overlay.visible = True
# viewer.text_overlay.text = "Window \nposition"
# viewer.text_overlay.font_size = 30
#
# viewer.dims.ndisplay = 3
# layer1 = viewer.add_labels(blobs, name="layer1", seed=0.03)
# viewer.camera.angles = (30, 40, 80)
# layer1.opacity = 1
#
# make_screenshot(viewer)

# %%
# ChapterConfig.clean("Viewer Interface")
